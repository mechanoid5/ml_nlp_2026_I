# %% [markdown]
# **тематическое моделирование**
#
# _Евгений Борисов <esborisov@sevsu.ru>_

# %%
import numpy as np
import pandas as pd
from tqdm.auto import tqdm

pd.options.display.precision = 2 
pd.options.display.max_colwidth = 200 
tqdm.pandas()

# %% [markdown]
# Topic extraction with Non-negative Matrix Factorization and Latent Dirichlet Allocation
# http://scikit-learn.org/stable/auto_examples/applications/plot_topics_extraction_with_nmf_lda.html

# %%
# разложение частотной матрицы [ слова x документы ]  
#
# получаем матрицу с описанием тем [ слова х темы ]   
# и матрицу вероятностей событий "тема описывает документ"  [ темы х документы ]
# 
# [ слова x документы ] = [ слова х темы ] * [ темы х документы ]
# 
# p(w|d) = p(w|t) * p(t|d)

# %% [markdown]
# # загрузка данных

# %%
# загружаем тексты
data = pd.read_pickle('../data/news.pkl.gz')
display( len(data) )
display( data.sample(2) )
# Out:
# 3196
#                                                                                                                                                                                                          text  \
# 2248  Пермское региональное управление Следственного комитета инициировало проверку появившейся в СМИ информации о том, что кондуктор выгнала 11-летнего школьника из автобуса не на остановке в мороз из-...
# 3117  Юлия Маркова ИТАР-ТАСС. Новости культуры (оперативная лента) На Колыме\nуспешно завершился этнокультурный образовательный эксперимент по\nпрограмме поддержки северных народов Администрация Магадан...
#
#            tag
# 2248  incident
# 3117    social

# %%
display( len( data.drop_duplicates('text') ) )
# Out:
# 3196

# %% [markdown]
# # токенайзер

# %%
# NLTK package manager
# import nltk
# nltk.download()

# %%
import re
from nltk.tokenize import word_tokenize as nltk_tokenize_word

# %%
# def tokenizer(text):
#     return [
#             t for t in nltk_tokenize_word( # разбиваем текст на слова
#                 re.sub(r'</?[a-z]+>',' ',text), # удаляем xml tag 
#                 language='russian'
#             ) 
#         ]

# %%
# stemmer = SnowballStemmer('russian')

from nltk.corpus import stopwords as nltk_stopwords
stopwords = set(nltk_stopwords.words('russian'))

def tokenizer(text,stopwords=stopwords):
    return [
            t for t in nltk_tokenize_word( # разбиваем текст на слова
                re.sub(r'</?[a-z]+>',' ',text), # удаляем xml tag 
                language='russian'
            ) 
            if not (
               False
               or (len(t)<3) # выкидываем очень короткие слова
               or re.match(r'^[^a-zA-ZЁёА-я]+$', t) # выкидываем токены не содержащие букв
               or re.match(r'^(\w)\1+$', t)  # выкидываем токены из одного повторяющегося символа
               or re.match(r'^[^a-zA-ZЁёА-я].*$', t)  # выкидываем токены начинающиеся не с буквы
               or (t in stopwords) # выкидываем предлоги, союзы и т.п.    
            )
        ]

# %% [markdown]
# # выполняем частотный анализ

# %%
# from sklearn.feature_extraction.text import CountVectorizer
# tf_model = CountVectorizer(
#         min_df=.01, # выкидываем очень редкие слова
#         max_df=.10, # выкидываем очень частые слова
#         tokenizer=tokenizer, # ф-ция токенайзер
#         token_pattern=None, # отключаем дефолтный токенайзер
#         # binary=True,
#     )

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tf_model = TfidfVectorizer(
        min_df=.01, # выкидываем очень редкие слова
        max_df=.10, # выкидываем очень частые слова
        use_idf=False, # не используем обратную частоту
        norm='l2', # нормируем TF
        tokenizer=tokenizer, # ф-ция токенайзер
        token_pattern=None, # отключаем дефолтный токенайзер
    )

# %%
# %%time

data_tf = tf_model.fit_transform( data['text'] )

display(data_tf.shape)
# Out:
# (3196, 2021)
# CPU times: user 4.62 s, sys: 13.2 ms, total: 4.63 s
# Wall time: 4.64 s

# %%
vocab = sorted(tf_model.vocabulary_)
display(len(vocab))
display(vocab)
# Out:
# 2021
# ['adobe',
#  'afisha.tut.by',
#  'apple',
#  'audi',
#  'auto.tut.by',
#  'facebook',
#  'finance.tut.by',
#  'flash',
#  'html5',
#  'http',
#  'javascript',
#  'journal',
#  'kia',
#  'lenta.ru',
#  'news',
#  'player',
#  'realty.tut.by',
#  'regnum',
#  'reuters',
#  'sport.tut.by',
#  'street',
#  'telegram',
#  'the',
#  'times',
#  'tut.by',
#  'twitter',
#  'volkswagen',
#  'wall',
#  'youtube',
#  'абсолютно',
#  'аварии',
#  'авария',
#  'августа',
#  'августе',
#  'авто',
#  'автобуса',
#  'автомобилей',
#  'автомобилем',
#  'автомобили',
#  'автомобиль',
#  'автомобиля',
#  'автор',
#  'авторы',
#  'агентства',
#  'агентство',
#  'администрации',
#  'адрес',
#  'актер',
#  'активно',
#  'активность',
#  'акции',
#  'акций',
#  'александр',
#  'александра',
#  'александром',
#  'алексей',
#  'алеппо',
#  'американская',
#  'американские',
#  'американский',
#  'американских',
#  'американского',
#  'американской',
#  'америки',
#  'анализ',
#  'аналитики',
#  'андрей',
#  'андрея',
#  'анна',
#  'армии',
#  'ассоциации',
#  'атмосферу',
#  'базе',
#  'базовой',
#  'банк',
#  'банка',
#  'безопасности',
#  'беларуси',
#  'беларусь',
#  'белорусов',
#  'белорусская',
#  'белорусские',
#  'белорусский',
#  'белорусских',
#  'белорусского',
#  'белорусской',
#  'белорусы',
#  'белта',
#  'бизнес',
#  'бизнеса',
#  'билеты',
#  'благодаря',
#  'ближайшее',
#  'ближайшие',
#  'боевиков',
#  'больнице',
#  'больницу',
#  'больницы',
#  'большая',
#  'большие',
#  'большим',
#  'большинстве',
#  'большинство',
#  'большого',
#  'большое',
#  'большой',
#  'большом',
#  'большую',
#  'бороться',
#  'борту',
#  'борьбе',
#  'борьбы',
#  'браузер',
#  'будем',
#  'буду',
#  'будущего',
#  'будущем',
#  'буквально',
#  'бумаги',
#  'бывает',
#  'бывшего',
#  'бывший',
#  'быстро',
#  'бюджета',
#  'вадим',
#  'важнейших',
#  'важно',
#  'валерий',
#  'вариант',
#  'ваш',
#  'вашингтон',
#  'ведет',
#  'ведомства',
#  'ведомство',
#  'ведут',
#  'века',
#  'великобритании',
#  'вернуть',
#  'вернуться',
#  'вероятно',
#  'версии',
#  'версию',
#  'версия',
#  'весной',
#  'вести',
#  'весь',
#  'весьма',
#  'вечером',
#  'вещи',
#  'взгляд',
#  'взрыв',
#  'взрыва',
#  'взял',
#  'взять',
#  'вид',
#  'вида',
#  'виде',
#  'видео',
#  'видно',
#  'видов',
#  'визита',
#  'виктор',
#  'виталий',
#  'включает',
#  'включая',
#  'вконтакте',
#  'владимир',
#  'владимира',
#  'властей',
#  'власти',
#  'вместе',
#  'вместо',
#  'вне',
#  'внимание',
#  'внимания',
#  'вновь',
#  'внутренних',
#  'внутри',
#  'вовсе',
#  'водитель',
#  'водителя',
#  'воды',
#  'военной',
#  'возбуждено',
#  'возле',
#  'возможно',
#  'возможностей',
#  'возможности',
#  'возможность',
#  'возраста',
#  'возрасте',
#  'войны',
#  'вокруг',
#  'вообще',
#  'вопрос',
#  'вопросам',
#  'вопросов',
#  'вопросы',
#  'ворота',
#  'восемь',
#  'воскресенье',
#  'воспользоваться',
#  'восточной',
#  'восьми',
#  'вошли',
#  'впервые',
#  'вполне',
#  'врачи',
#  'временем',
#  'времени',
#  'вроде',
#  'вряд',
#  'все-таки',
#  'всей',
#  'всем',
#  'всеми',
#  'всемирного',
#  'всему',
#  'вскоре',
#  'встреча',
#  'встрече',
#  'встречи',
#  'встречу',
#  'вся',
#  'всё',
#  'вторая',
#  'вторник',
#  'второго',
#  'второе',
#  'второй',
#  'втором',
#  'вторую',
#  'вторым',
#  'входит',
#  'входят',
#  'вчера',
#  'выбор',
#  'выбора',
#  'выборах',
#  'выборов',
#  'выборы',
#  'выбрать',
#  'выводу',
#  'выглядит',
#  'выиграл',
#  'выйти',
#  'выплаты',
#  'выпуска',
#  'вырос',
#  'выросли',
#  'высказывания',
#  'высокий',
#  'высокой',
#  'выступает',
#  'выступил',
#  'выступление',
#  'выступления',
#  'выход',
#  'выхода',
#  'выходит',
#  'выходные',
#  'выше',
#  'вышел',
#  'вышла',
#  'вышли',
#  'выяснили',
#  'выяснилось',
#  'выяснить',
#  'газа',
#  'газета',
#  'газеты',
#  'гаи',
#  'генеральный',
#  'германии',
#  'глава',
#  'главе',
#  'главная',
#  'главного',
#  'главное',
#  'главной',
#  'главный',
#  'главным',
#  'главных',
#  'главой',
#  'главу',
#  'главы',
#  'говорил',
#  'говорили',
#  'говорит',
#  'говорится',
#  'говорить',
#  'говоря',
#  'говорят',
#  'год',
#  'год.',
#  'годах',
#  'годов',
#  'годом',
#  'годы',
#  'гол',
#  'голову',
#  'голос',
#  'голосов',
#  'голосования',
#  'гораздо',
#  'город',
#  'города',
#  'городе',
#  'городской',
#  'гостей',
#  'гости',
#  'государств',
#  'государства',
#  'государственного',
#  'государственной',
#  'государственных',
#  'государство',
#  'готов',
#  'готова',
#  'готовы',
#  'градусов',
#  'граждан',
#  'гродно',
#  'грозит',
#  'групп',
#  'группа',
#  'группе',
#  'группу',
#  'группы',
#  'губернатор',
#  'давно',
#  'дает',
#  'дал',
#  'далее',
#  'далеко',
#  'дали',
#  'дальше',
#  'данная',
#  'данного',
#  'данной',
#  'данном',
#  'данные',
#  'данный',
#  'данным',
#  'данных',
#  'дарья',
#  'дать',
#  'дважды',
#  'две',
#  'двигатель',
#  'движение',
#  'движения',
#  'двое',
#  'двумя',
#  'двух',
#  'девять',
#  'действие',
#  'действий',
#  'действительно',
#  'действия',
#  'дек',
#  'декабре',
#  'дел',
#  'дела',
#  'делает',
#  'делам',
#  'делать',
#  'делают',
#  'деле',
#  'дело',
#  'делу',
#  'денег',
#  'денис',
#  'день',
#  'деньги',
#  'департамента',
#  'депутат',
#  'депутата',
#  'деревне',
#  'деревни',
#  'десять',
#  'детали',
#  'детей',
#  'дети',
#  'детям',
#  'деятельности',
#  'деятельность',
#  'джона',
#  'дизайн',
#  'динамо',
#  'директор',
#  'директора',
#  'дмитрий',
#  'дней',
#  'днем',
#  'дни',
#  'днр',
#  'дня',
#  'добавил',
#  'добиться',
#  'добычи',
#  'довольно',
#  'договор',
#  'договора',
#  'документ',
#  'документа',
#  'документов',
#  'документы',
#  'долго',
#  'должен',
#  'должна',
#  'должно',
#  'должности',
#  'должность',
#  'должны',
#  'долларов',
#  'доля',
#  'дом',
#  'дома',
#  'доме',
#  'домов',
#  'домой',
#  'дональд',
#  'дональда',
#  'дополнительные',
#  'дороге',
#  'дороги',
#  'дорогу',
#  'дорожного',
#  'доставлены',
#  'достаточно',
#  'достижения',
#  'доступ',
#  'друг',
#  'друга',
#  'другая',
#  'другие',
#  'другим',
#  'другими',
#  'других',
#  'другого',
#  'другое',
#  'другом',
#  'дтп',
#  'думаю',
#  'евгений',
#  'евро',
#  'европе',
#  'европейский',
#  'европейского',
#  'европейской',
#  'европы',
#  'единственный',
#  'ежегодно',
#  'екатеринбурге',
#  'елена',
#  'ещё',
#  'ждать',
#  'ждет',
#  'женщин',
#  'женщина',
#  'женщины',
#  'живет',
#  'животных',
#  'жизни',
#  'жизнь',
#  'жителей',
#  'жители',
#  'житель',
#  'жителям',
#  'жить',
#  'журналистов',
#  'жюри',
#  'забил',
#  'зависимости',
#  'зависит',
#  'задача',
#  'задачи',
#  'заключения',
#  'заключили',
#  'закон',
#  'закона',
#  'законодательства',
#  'зал',
#  'зале',
#  'заместитель',
#  'заметил',
#  'заметили',
#  'заметно',
#  'занимает',
#  'занимается',
#  'занимался',
#  'заниматься',
#  'занимаются',
#  'занял',
#  'западной',
#  'заранее',
#  'заседание',
#  'заседании',
#  'заседания',
#  'затем',
#  'зато',
#  'захарченко',
#  'защите',
#  'защиты',
#  'заявил',
#  'заявила',
#  'заявили',
#  'заявление',
#  'заявления',
#  'звание',
#  'звезды',
#  'здании',
#  'здания',
#  'здоровья',
#  'здравоохранения',
#  'земле',
#  'земли',
#  'знает',
#  'знаете',
#  'значение',
#  'значит',
#  'значительно',
#  'знаю',
#  'знают',
#  'золотой',
#  'зрения',
#  'зрителей',
#  'иван',
#  'игорь',
#  'игр',
#  'игра',
#  'играет',
#  'играть',
#  'игрок',
#  'игроков',
#  'игру',
#  'игры',
#  'идет',
#  'идея',
#  'идти',
#  'идут',
#  'избежать',
#  'избранного',
#  'избранный',
#  'известно',
#  'известный',
#  'известных',
#  'издание',
#  'издания',
#  'изменений',
#  'изменения',
#  'изменить',
#  'изначально',
#  'изображение',
#  'им.',
#  'имеет',
#  'имени',
#  'именно',
#  'иметь',
#  'имеют',
#  'ими',
#  'имущества',
#  'имя',
#  'иначе',
#  'иностранных',
#  'института',
#  'интервью',
#  'интерес',
#  'интересно',
#  'интересов',
#  'интересы',
#  'интернет',
#  'интернете',
#  'интерфакс',
#  'информации',
#  'информацию',
#  'информация',
#  'инцидент',
#  'инцидента',
#  'ирина',
#  'искать',
#  'исключительно',
#  'использования',
#  'использовать',
#  'исследование',
#  'исследований',
#  'исследования',
#  'исследователи',
#  'истории',
#  'историю',
#  'история',
#  'источник',
#  'источника',
#  'источники',
#  'источников',
#  'исходя',
#  'италии',
#  'итогам',
#  'итоге',
#  'итоги',
#  'июля',
#  'каждая',
#  'каждого',
#  'каждой',
#  'каждый',
#  'кажется',
#  'казалось',
#  'как-то',
#  'какие',
#  'какие-то',
#  'каким',
#  'какой-то',
#  'кампании',
#  'канал',
#  'кандидата',
#  'картина',
#  'картины',
#  'карьеру',
#  'касается',
#  'категории',
#  'качестве',
#  'качество',
#  'кв.',
#  'квадратных',
#  'квартиру',
#  'квартиры',
#  'киев',
#  'киеве',
#  'километров',
#  'кино',
#  'китае',
#  'китая',
#  'клиентов',
#  'клуб',
#  'клуба',
#  'км/ч',
#  'книги',
#  'кого',
#  'кодекса',
#  'количество',
#  'команд',
#  'команда',
#  'команде',
#  'команду',
#  'команды',
#  'комиссии',
#  'комиссия',
#  'комитет',
#  'комитета',
#  'комментариев',
#  'комментарии',
#  'компанией',
#  'компании',
#  'компаний',
#  'компанию',
#  'компания',
#  'комплекс',
#  'комплекса',
#  'комплектации',
#  'кому',
#  'конец',
#  'конкурса',
#  'контракт',
#  'контроль',
#  'контроля',
#  'конференции',
#  'конфликт',
#  'конфликта',
#  'конца',
#  'конце',
#  'концерт',
#  'коренных',
#  'корпорации',
#  'корпорация',
#  'которого',
#  'которое',
#  'которой',
#  'котором',
#  'которому',
#  'которую',
#  'которым',
#  'которыми',
#  'крайне',
#  'края',
#  'кроссовера',
#  'крупных',
#  'кстати',
#  'кто-то',
#  'кубка',
#  'культуры',
#  'купить',
#  'легко',
#  'летом',
#  'либо',
#  'лиги',
#  'лидер',
#  'лидера',
#  'лидеров',
#  'лидером',
#  'ликвидации',
#  'линии',
#  'литра',
#  'лиц',
#  'лица',
#  'лицо',
#  'лицом',
#  'лично',
#  'личного',
#  'лишь',
#  'лнр',
#  'лошадиных',
#  'лукашенко',
#  'лучшая',
#  'лучшего',
#  'лучшие',
#  'лучший',
#  'лучшим',
#  'лучших',
#  'любовь',
#  'любой',
#  'любые',
#  'людей',
#  'люди',
#  'людьми',
#  'людям',
#  'мае',
#  'максимально',
#  'мало',
#  'малочисленных',
#  'мальчик',
#  'мальчика',
#  'мама',
#  'манчестер',
#  'марки',
#  'марта',
#  'марте',
#  'материале',
#  'материалов',
#  'материалы',
#  'матч',
#  'матча',
#  'матчах',
#  'матче',
#  'матчей',
#  'машин',
#  'машина',
#  'машине',
#  'машину',
#  'машины',
#  'мая',
#  'мвд',
#  'международного',
#  'международной',
#  'международный',
#  'международных',
#  'менее',
#  'меньше',
#  'мере',
#  'мероприятий',
#  'мероприятия',
#  'меры',
#  'мест',
#  'места',
#  'местах',
#  'месте',
#  'местные',
#  'местных',
#  'место',
#  'месяц',
#  'месяца',
#  'месяцев',
#  'метров',
#  'мид',
#  'миллиардов',
#  'миллиона',
#  'миллионов',
#  'минимум',
#  'министерства',
#  'министерство',
#  'министр',
#  'министра',
#  'министров',
#  'минск',
#  'минска',
#  'минске',
#  'минского',
#  'минской',
#  'минут',
#  'минуты',
#  'мир',
#  'мира',
#  'мире',
#  'мировой',
#  'миру',
#  'михаил',
#  'млн',
#  'млн.',
#  'млрд',
#  'мнение',
#  'мнению',
#  'многие',
#  'многих',
#  'многое',
#  'множество',
#  'мог',
#  'могла',
#  'могли',
#  'могу',
#  'моделей',
#  'модели',
#  'модель',
#  'моего',
#  'моей',
#  'можем',
#  'можете',
#  'мои',
#  'молодой',
#  'молодым',
#  'момент',
#  'момента',
#  'моря',
#  'москва',
#  'москве',
#  'москвы',
#  'московского',
#  'московской',
#  'мощность',
#  'мощностью',
#  'мск',
#  'мужчин',
#  'мужчина',
#  'мужчину',
#  'мужчины',
#  'музыка',
#  'музыки',
#  'музыку',
#  'мчс',
#  'мяч',
#  'набрал',
#  'наверное',
#  'награду',
#  'награды',
#  'надежда',
#  'надежду',
#  'надежды',
#  'назад',
#  'назвал',
#  'назвала',
#  'назвали',
#  'назван',
#  'название',
#  'названием',
#  'назвать',
#  'называют',
#  'наиболее',
#  'найти',
#  'накануне',
#  'наличие',
#  'наличии',
#  'нам',
#  'намерен',
#  'намерена',
#  'нами',
#  'намного',
#  'наоборот',
#  'нападающий',
#  'написал',
#  'напоминает',
#  'направлении',
#  'направлены',
#  'например',
#  'народ',
#  'народа',
#  'народного',
#  'народов',
#  'нарушение',
#  'нарушения',
#  'населения',
#  'насколько',
#  'настолько',
#  'настоящее',
#  'настоящий',
#  'наталья',
#  'находилась',
#  'находились',
#  'находился',
#  'находится',
#  'находятся',
#  'национального',
#  'национальной',
#  'начал',
#  'начала',
#  'начале',
#  'начали',
#  'начало',
#  'начальник',
#  'начальника',
#  'начать',
#  'начинает',
#  'начинается',
#  'начинают',
#  'начиная',
#  'начнет',
#  'начнется',
#  'наш',
#  'наша',
#  'нашего',
#  'нашей',
#  'нашем',
#  'наши',
#  'нашим',
#  'наших',
#  'нашли',
#  'нашу',
#  'небольшой',
#  'невозможно',
#  'недавно',
#  'неделе',
#  'недели',
#  'неделю',
#  'неизвестно',
#  'некоторые',
#  'некоторых',
#  'нем',
#  'немного',
#  'нему',
#  'необходимо',
#  'необходимости',
#  'необходимость',
#  'неоднократно',
#  'неожиданно',
#  'нескольких',
#  'несмотря',
#  'нефти',
#  'нефть',
#  'ниже',
#  'никак',
#  'никаких',
#  'никакого',
#  'николай',
#  'никто',
#  'ними',
#  'новая',
#  'новинка',
#  'новинки',
#  'нового',
#  'новое',
#  'новой',
#  'новом',
#  'новости',
#  'новую',
#  'новые',
#  'новый',
#  'новым',
#  'новых',
#  'номер',
#  'номинации',
#  'ночь',
#  'ночью',
#  'ноябре',
#  'нравится',
#  'нужен',
#  'нужно',
#  'нужны',
#  'нынешнего',
#  'нынешнем',
#  'нью-йорке',
#  'оао',
#  'оба',
#  'обе',
#  'обеспечения',
#  'обеспечить',
#  'областного',
#  'областной',
#  'обнаружили',
#  'обновлено',
#  'оборудования',
#  'образ',
#  'образования',
#  'образом',
#  'обращения',
#  'обстоятельства',
#  'обсудить',
#  'общая',
#  'общего',
#  'общей',
#  'общем',
#  'общества',
#  'общественного',
#  'общий',
#  'объект',
#  'объектов',
#  'объем',
#  'объеме',
#  'объявил',
#  'объявила',
#  'объясняет',
#  'обычно',
#  'обязательно',
#  ...]

# %% [markdown]
# # извлечение списка тем и ключевых слов

# %%
# извлекаем из модели список тем и ключевых слов
def extract_topics( components, feature_names, n_top_words=3 ):
    return {
        topic_idx : [ feature_names[i] for i in topic.argsort()[:-n_top_words-1:-1] ]
        for topic_idx, topic in enumerate(components)
    }

# %%
# from sklearn.decomposition import LatentDirichletAllocation
# # LDA - латентное размещение Дирихле
# tm_model = LatentDirichletAllocation( 
#         n_components=10, 
#         max_iter=5,
#         learning_method='online', 
#         learning_offset=50.,
#         random_state=0, 
#     )

# %%
from sklearn.decomposition import NMF
# NMF (generalized Kullback-Leibler divergence) 

tm_model = NMF( 
        n_components=10,
        random_state=1, 
        beta_loss='kullback-leibler', 
        solver='mu', 
        max_iter=1000, 
        l1_ratio=.5 
    )

# %%
# %%time 

data['topic_id'] = np.argmax( tm_model.fit_transform(data_tf),axis=1)
# Out:
# CPU times: user 6.86 s, sys: 4.7 ms, total: 6.86 s
# Wall time: 2.11 s

# %%
# список тем и ключевых слов
topics = extract_topics( tm_model.components_, vocab )
display( topics )
# Out:
# {0: ['беларуси', 'tut.by', 'беларусь'],
#  1: ['президент', 'президента', 'трамп'],
#  2: ['рублей', 'компании', 'долларов'],
#  3: ['результате', 'дтп', 'водитель'],
#  4: ['версия', 'новый', 'видео'],
#  5: ['народов', 'севера', 'коренных'],
#  6: ['ученые', 'специалисты', 'алеппо'],
#  7: ['савченко', 'украины', 'суд'],
#  8: ['место', 'динамо', 'чемпионата'],
#  9: ['стал', 'фильм', 'мира']}

# %% [markdown]
# ---

# %%
# распределение текстов по темам
# data.groupby(['topic_id']).size().plot.bar(rot=0)

# %%
topics_ = { k:f'{k}: ' + ' | '.join(v) for k,v in topics.items() }
tags = sorted(set(data['tag']))

topic_tags = (
    data[['tag','topic_id']]
    .groupby('topic_id')['tag']
    .apply(lambda t_tags: { t: len([w for w in t_tags if w==t]) for t in tags } )
    .reset_index()
    .rename(columns={'level_1':'tag','tag':'count',})
    .apply(lambda d: d.map(topics_) if d.name =='topic_id' else d)
    .pivot(index='topic_id', columns='tag', values='count')
)

display( topic_tags.style.background_gradient(cmap='Blues') )
# Out:
# <style type="text/css">
# #T_35e20_row0_col0, #T_35e20_row6_col1 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_35e20_row0_col1 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_35e20_row0_col2 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_35e20_row0_col3 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_35e20_row0_col4, #T_35e20_row1_col9, #T_35e20_row2_col12, #T_35e20_row5_col12, #T_35e20_row6_col12, #T_35e20_row7_col12 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_35e20_row0_col5 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_35e20_row0_col6, #T_35e20_row0_col7, #T_35e20_row0_col12, #T_35e20_row1_col5, #T_35e20_row2_col2, #T_35e20_row2_col11, #T_35e20_row3_col4, #T_35e20_row4_col0, #T_35e20_row5_col9, #T_35e20_row6_col3, #T_35e20_row6_col8, #T_35e20_row8_col10, #T_35e20_row9_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_35e20_row0_col8, #T_35e20_row2_col1, #T_35e20_row3_col3, #T_35e20_row5_col10, #T_35e20_row7_col3, #T_35e20_row7_col10, #T_35e20_row9_col5 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_35e20_row0_col9 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_35e20_row0_col10, #T_35e20_row1_col1 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_35e20_row0_col11 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_35e20_row1_col0, #T_35e20_row1_col4, #T_35e20_row1_col7, #T_35e20_row1_col8, #T_35e20_row1_col11, #T_35e20_row1_col12, #T_35e20_row3_col1, #T_35e20_row3_col7, #T_35e20_row3_col10, #T_35e20_row3_col12, #T_35e20_row4_col6, #T_35e20_row4_col8, #T_35e20_row4_col12, #T_35e20_row6_col0, #T_35e20_row6_col7, #T_35e20_row6_col10, #T_35e20_row7_col0, #T_35e20_row7_col2, #T_35e20_row7_col6, #T_35e20_row7_col7, #T_35e20_row7_col8, #T_35e20_row8_col2, #T_35e20_row8_col3, #T_35e20_row8_col4, #T_35e20_row8_col5, #T_35e20_row8_col6, #T_35e20_row8_col7, #T_35e20_row8_col8, #T_35e20_row8_col9, #T_35e20_row8_col12, #T_35e20_row9_col4, #T_35e20_row9_col8 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_35e20_row1_col2 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_35e20_row1_col3, #T_35e20_row2_col4 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_35e20_row1_col6, #T_35e20_row3_col6, #T_35e20_row8_col1, #T_35e20_row9_col6 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_35e20_row1_col10 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_35e20_row2_col0 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_35e20_row2_col3, #T_35e20_row4_col3, #T_35e20_row9_col3, #T_35e20_row9_col11 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_35e20_row2_col5 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_35e20_row2_col6 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_35e20_row2_col7 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_35e20_row2_col8, #T_35e20_row2_col9, #T_35e20_row3_col9, #T_35e20_row9_col10 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_35e20_row2_col10, #T_35e20_row3_col5, #T_35e20_row4_col4, #T_35e20_row4_col5, #T_35e20_row5_col8 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_35e20_row3_col0 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_35e20_row3_col2, #T_35e20_row5_col0, #T_35e20_row6_col2, #T_35e20_row8_col0, #T_35e20_row9_col0, #T_35e20_row9_col2 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_35e20_row3_col8, #T_35e20_row6_col4 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_35e20_row3_col11, #T_35e20_row4_col10, #T_35e20_row6_col6 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_35e20_row4_col1 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_35e20_row4_col2, #T_35e20_row7_col9, #T_35e20_row8_col11 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_35e20_row4_col7 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_35e20_row4_col9 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_35e20_row4_col11 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_35e20_row5_col1 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_35e20_row5_col2 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_35e20_row5_col3 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_35e20_row5_col4 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_35e20_row5_col5 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_35e20_row5_col6 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_35e20_row5_col7, #T_35e20_row6_col9, #T_35e20_row9_col9 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_35e20_row5_col11 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_35e20_row6_col5 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_35e20_row6_col11 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_35e20_row7_col1 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_35e20_row7_col4 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_35e20_row7_col5 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_35e20_row7_col11 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_35e20_row9_col7 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_35e20_row9_col12 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# </style>
# <table id="T_35e20">
#   <thead>
#     <tr>
#       <th class="index_name level0" >tag</th>
#       <th id="T_35e20_level0_col0" class="col_heading level0 col0" >auto</th>
#       <th id="T_35e20_level0_col1" class="col_heading level0 col1" >culture</th>
#       <th id="T_35e20_level0_col2" class="col_heading level0 col2" >economics</th>
#       <th id="T_35e20_level0_col3" class="col_heading level0 col3" >health</th>
#       <th id="T_35e20_level0_col4" class="col_heading level0 col4" >incident</th>
#       <th id="T_35e20_level0_col5" class="col_heading level0 col5" >politics</th>
#       <th id="T_35e20_level0_col6" class="col_heading level0 col6" >realty</th>
#       <th id="T_35e20_level0_col7" class="col_heading level0 col7" >reclama</th>
#       <th id="T_35e20_level0_col8" class="col_heading level0 col8" >science</th>
#       <th id="T_35e20_level0_col9" class="col_heading level0 col9" >social</th>
#       <th id="T_35e20_level0_col10" class="col_heading level0 col10" >sport</th>
#       <th id="T_35e20_level0_col11" class="col_heading level0 col11" >tech</th>
#       <th id="T_35e20_level0_col12" class="col_heading level0 col12" >woman</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >topic_id</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_35e20_level0_row0" class="row_heading level0 row0" >0: беларуси | tut.by | беларусь</th>
#       <td id="T_35e20_row0_col0" class="data row0 col0" >27</td>
#       <td id="T_35e20_row0_col1" class="data row0 col1" >64</td>
#       <td id="T_35e20_row0_col2" class="data row0 col2" >38</td>
#       <td id="T_35e20_row0_col3" class="data row0 col3" >13</td>
#       <td id="T_35e20_row0_col4" class="data row0 col4" >11</td>
#       <td id="T_35e20_row0_col5" class="data row0 col5" >26</td>
#       <td id="T_35e20_row0_col6" class="data row0 col6" >40</td>
#       <td id="T_35e20_row0_col7" class="data row0 col7" >30</td>
#       <td id="T_35e20_row0_col8" class="data row0 col8" >6</td>
#       <td id="T_35e20_row0_col9" class="data row0 col9" >55</td>
#       <td id="T_35e20_row0_col10" class="data row0 col10" >25</td>
#       <td id="T_35e20_row0_col11" class="data row0 col11" >26</td>
#       <td id="T_35e20_row0_col12" class="data row0 col12" >30</td>
#     </tr>
#     <tr>
#       <th id="T_35e20_level0_row1" class="row_heading level0 row1" >1: президент | президента | трамп</th>
#       <td id="T_35e20_row1_col0" class="data row1 col0" >0</t

# %%
( # распределение количества текстов по темам с долями меток
    topic_tags
    .plot.barh(stacked=True) #,rot=0)
    .legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
)

# %% [markdown]
# ---

# %%
data['keywords'] = data['topic_id'].map(topics)
display( data.sample(4) )
# Out:
#                                                                                                                                                                                                          text  \
# 2315  Сотрудницу полиции, которая стала виновником ДТП с двум погибшими в Подмосковье, уволили из органов внутренних дел, сообщает МВД. Подозреваемая находилась в состоянии алкогольного опьянения. Она з...
# 2763  Компания Apple добавит второй слот для SIM-карты в новом iPhone, который представят в конце 2017 года, сообщает Gizmochina. В начале 2016 года Apple подала две патентные заявки, одна из которых оп...
# 1967  НЬЮ-ЙОРК (Рейтер) - Индексы S&P 500 и Nasdaq Composite снизились в понедельник после шести дней роста из-за падения акций технологического сектора, а ралли энергетических акций сошло на нет, так к...
# 1650  СМИ: Россия выплатит 6 тысяч евро фигуранту дела Немцова\n\nНа аналогичные выплаты могут рассчитывать и другие фигуранты дела\n\nРоссийские власти предложили Темирлану Эскерханову — одному из фигу...
#
#             tag  topic_id                      keywords
# 2315   incident         3   [результате, дтп, водитель]
# 2763       tech         4        [версия, новый, видео]
# 1967  economics         2  [рублей, компании, долларов]
# 1650   politics         7      [савченко, украины, суд]

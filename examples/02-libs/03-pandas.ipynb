# %% [markdown]
# **pandas demo**
#
# _Евгений Борисов <esborisov@sevsu.ru>_

# %% [markdown]
# ---

# %% [markdown]
# Pandas: Chart Visualization
# https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html

# %% [markdown]
# Формат таблиц в pandas
# https://habr.com/ru/post/521894/

# %%
import pandas as pd
import numpy as np
from numpy import random as rng

# %%
pd.options.display.max_colwidth = 200 # ширина таблицы pandas при печати
np.set_printoptions(precision=2) # вывод на печать до 2 знака

# %% [markdown]
# # eurostat

# %%
# !pip3 install eurostat

# %%
# статистика по странам Евросоюза
# https://ec.europa.eu/eurostat
import eurostat

# %%
# список тем в источнике
toc = eurostat.get_toc_df().drop_duplicates()
toc.sample(10)
# Out:
#                                                                                                                                                                                            title  \
# 6280                                      Internet facilities, robotics, precision farming and machinery for livestock management in farms by economic size of farm, farm type and NUTS 2 region
# 4781                                                                                                                          At-risk-of-poverty rate anchored at a point in time by sex and age
# 2033                                                                                       Gross production of electricity and derived heat from combustible fuels by type of plant and operator
# 2639                                                                                                      Cost of CVT courses by type and size class - % of total labour cost of all enterprises
# 5751                                                                                                                                           Education indicators by NUTS 2 region (1998-2012)
# 1588                                                                                                                                                     Area of wooded land (EFA questionnaire)
# 6155  Importance of barriers met for engaging in international sourcing of activities by sourcing status and economic activity (figures and %) - collection round 2007 - experimental statistics
# 3552                                                                                                                                                                     Gross disposable income
# 6645                                                                                                                    Direct investment balance with the rest of the world, ENP-East countries
# 1740                                                                                                                Mining and quarrying by employment size class (NACE Rev. 1.1, C) (1995-2001)
#
#                 code     type       last update of data  \
# 6280      EF_MP_DIGI  dataset  2025-12-12T11:00:00+0100
# 4781        ILC_LI20  dataset  2009-03-27T11:00:00+0100
# 2033   NRG_IND_PEHCF  dataset  2026-01-15T11:00:00+0100
# 2639    TRNG_CVT_16S  dataset  2024-06-07T23:00:00+0200
# 5751     EDUC_REGIND  dataset  2019-03-15T23:00:00+0100
# 1588    FOR_AREA_EFA  dataset  2026-01-04T11:00:00+0100
# 6155        ISS_BARR  dataset  2010-02-19T11:00:00+0100
# 3552        TEINA090  dataset  2026-01-19T23:00:00+0100
# 6645   ENPE_BOP_FDI6  dataset  2025-04-15T23:00:00+0200
# 1740  SBS_SC_2D_MI95  dataset  2016-05-24T23:00:00+0200
#
#      last table structure change data start data end
# 6280    2025-12-12T11:00:00+0100       2023     2023
# 4781    2023-12-21T23:00:00+0100       1998     2003
# 2033    2025-06-16T11:00:00+0200       1990     2024
# 2639    2024-01-03T23:00:00+0100       2005     2020
# 5751    2024-01-10T11:00:00+0100       1998     2012
# 1588    2025-12-18T23:00:00+0100       1990     2024
# 6155    2024-10-14T23:00:00+0200       2007     2007
# 3552    2026-01-12T23:00:00+0100    2022-Q4  2025-Q3
# 6645    2025-04-15T23:00:00+0200       2005     2024
# 1740    2023-12-21T23:00:00+0100       1995     2001

# %%
# Animal populations by NUTS 2 regions
df = eurostat.get_data_df('tgs00045')
display(len(df))
df.sample(10)
# Out:
# 1313
#      freq animals    unit geo\TIME_PERIOD     2013     2014     2015     2016  \
# 515     A  A2300F  THS_HD            PT17     7.84     8.01     8.88     8.90
# 885     A   A4100  THS_HD            BE32     8.09      NaN      NaN     7.29
# 1265    A   A4200  THS_HD            RO22   328.50   361.70   367.80   371.80
# 300     A  A2300F  THS_HD            BE10     0.18     0.28     0.27     0.10
# 1177    A   A4200  THS_HD            FRI3   405.00   403.00   385.00   368.00
# 135     A   A2000  THS_HD            FRY4    29.00    29.00    30.00    31.00
# 523     A  A2300F  THS_HD            PT30     0.27     0.31     0.31     0.27
# 74      A   A2000  THS_HD            EL52   181.50   185.90   157.40   143.10
# 607     A   A3100  THS_HD            DK04  4421.00  4542.00  4551.00  4551.00
# 820     A   A3100  THS_HD            RS12      NaN  1324.85  1342.46  1248.66
#
#          2017     2018     2019     2020     2021     2022     2023     2024
# 515      8.82     8.94     8.43     8.30     8.20     7.50      NaN      NaN
# 885       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1265   377.80   390.40   425.80   426.30   379.50   385.00   342.40   332.20
# 300      0.21     0.21     0.22     0.21     0.21     0.27     0.26     0.26
# 1177   369.00   365.69   358.83   369.55   368.33   340.26   323.81   317.62
# 135     30.83    30.15    29.29    27.21    25.17    24.29    22.95    22.69
# 523      0.32     0.30     0.30     0.23     0.21     0.22     0.19     0.13
# 74     143.00   138.20   134.50   160.10   161.90   147.70   147.83   143.04
# 607   4551.00  4476.00  4564.00  4731.00  4645.00  4119.00  4053.00  4068.00
# 820   1220.00  1236.00  1230.00  1261.00  1212.00  1132.38   939.89  1027.25

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1313 entries, 0 to 1312
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   freq             1313 non-null   object
#  1   animals          1313 non-null   object
#  2   unit             1313 non-null   object
#  3   geo\TIME_PERIOD  1313 non-null   object
#  4   2013             994 non-null    float64
#  5   2014             953 non-null    float64
#  6   2015             977 non-null    float64
#  7   2016             1022 non-null   float64
#  8   2017             976 non-null    float64
#  9   2018             960 non-null    float64
#  10  2019             964 non-null    float64
#  11  2020             976 non-null    float64
#  12  2021             974 non-null    float64
#  13  2022             981 non-null    float64
#  14  2023             1091 non-null   float64
#  15  2024             1098 non-null   float64
# dtypes: float64(12), object(4)
# memory usage: 164.3+ KB

# %%
n = rng.randint(len(df)) # выбираем запись
title = ' / '.join( df.iloc[n,:3].to_list() )
df.iloc[n,4:].plot(grid=True,figsize=(11,4), title=title)
# Out:
# <Axes: title={'center': 'A / A2300F / THS_HD'}>

# %% [markdown]
# # wikipedia

# %% [markdown]
# https://en.wikipedia.org/wiki/Demographics_of_India

# %%
# !pip3 install lxml
# Out:
# Collecting lxml
#   Downloading lxml-6.0.2-cp313-cp313-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl.metadata (3.6 kB)
# Downloading lxml-6.0.2-cp313-cp313-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl (5.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 6.3 MB/s  0:00:00 eta 0:00:01
# Installing collected packages: lxml
# Successfully installed lxml-6.0.2

# %%
import requests

url = 'https://en.wikipedia.org/wiki/Demographics_of_India'
headers = { 'User-Agent': 'My User Agent 1.0' }
answer = requests.get(url, headers=headers)
answer.raise_for_status()
tables = pd.read_html( answer.text)
display( len(tables) )
# Out:
# /tmp/ipykernel_37711/241269612.py:7: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html( answer.text)
# 49

# %%
df = tables[24]
#df = tables[22]
display( df.sample(5) )
# Out:
#    State or UT code    State or UT     Total     Male   Female  Difference
# 4                 5    Uttarakhand   1328844   704769   624075       80694
# 24               25  Daman and Diu     25880    13556    12314        1242
# 5                 6        Haryana   3297724  1802047  1495677      306370
# 18               19    West Bengal  10112599  5187264  4925335      261929
# 30               31    Lakshadweep      7088     3715     3373         342

# %%
# df = df[ df['State or UT']!='Total (India)'  ]
# df

# %%
display(df.info() )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35 entries, 0 to 34
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State or UT code  35 non-null     object
#  1   State or UT       35 non-null     object
#  2   Total             35 non-null     int64
#  3   Male              35 non-null     int64
#  4   Female            35 non-null     int64
#  5   Difference        35 non-null     int64
# dtypes: int64(4), object(2)
# memory usage: 1.9+ KB
# None

# %%
df = df.convert_dtypes()
display(df.info() )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35 entries, 0 to 34
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State or UT code  35 non-null     string
#  1   State or UT       35 non-null     string
#  2   Total             35 non-null     Int64
#  3   Male              35 non-null     Int64
#  4   Female            35 non-null     Int64
#  5   Difference        35 non-null     Int64
# dtypes: Int64(4), string(2)
# memory usage: 2.1 KB
# None

# %%
(
    df[['State or UT','Male','Female']]
    .set_index('State or UT')
    .plot.barh(figsize=(5,10),grid=True,)
    # .plot.barh(figsize=(5,10),grid=True, log=True)
)
# Out:
# <Axes: ylabel='State or UT'>

# %%
col = 'Difference'
# df[col] = pd.to_numeric(df[col].str.replace(',','').str.replace('−','-'))

# %%
df.style.bar(
    subset=[col],
      align='mid',
      color=['coral', 'yellowgreen'],
      vmin=df[col].min(),
      vmax=df[col].max()
     )
# Out:
# <style type="text/css">
# #T_ce03c_row0_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, yellowgreen 9.7%, transparent 9.7%);
# }
# #T_ce03c_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, yellowgreen 2.4%, transparent 2.4%);
# }
# #T_ce03c_row2_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, yellowgreen 15.5%, transparent 15.5%);
# }
# #T_ce03c_row3_col5, #T_ce03c_row12_col5, #T_ce03c_row16_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, yellowgreen 0.5%, transparent 0.5%);
# }
# #T_ce03c_row4_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, yellowgreen 5.1%, transparent 5.1%);
# }
# #T_ce03c_row5_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, yellowgreen 19.4%, transparent 19.4%);
# }
# #T_ce03c_row6_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, yellowgreen 8.9%, transparent 8.9%);
# }
# #T_ce03c_row7_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, yellowgreen 41.6%, transparent 41.6%);
# }
# #T_ce03c_row8_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, yellowgreen 100.0%, transparent 100.0%);
# }
# #T_ce03c_row9_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, yellowgreen 41.1%, transparent 41.1%);
# }
# #T_ce03c_row10_col5, #T_ce03c_row14_col5, #T_ce03c_row24_col5, #T_ce03c_row25_col5, #T_ce03c_row33_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, yellowgreen 0.1%, transparent 0.1%);
# }
# #T_ce03c_row11_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, yellowgreen 0.2%, transparent 0.2%);
# }
# #T_ce03c_row13_col5, #T_ce03c_row15_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, yellowgreen 0.7%, transparent 0.7%);
# }
# #T_ce03c_row17_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, yellowgreen 6.2%, transparent 6.2%);
# }
# #T_ce03c_row18_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, yellowgreen 16.6%, transparent 16.6%);
# }
# #T_ce03c_row19_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, yellowgreen 9.8%, transparent 9.8%);
# }
# #T_ce03c_row20_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, yellowgreen 10.8%, transparent 10.8%);
# }
# #T_ce03c_row21_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, yellowgreen 4.2%, transparent 4.2%);
# }
# #T_ce03c_row22_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, yellowgreen 30.8%, transparent 30.8%);
# }
# #T_ce03c_row23_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, yellowgreen 28.8%, transparent 28.8%);
# }
# #T_ce03c_row26_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, yellowgreen 50.4%, transparent 50.4%);
# }
# #T_ce03c_row27_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, yellowgreen 16.1%, transparent 16.1%);
# }
# #T_ce03c_row28_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, yellowgreen 12.6%, transparent 12.6%);
# }
# #T_ce03c_row29_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, yellowgreen 0.3%, transparent 0.3%);
# }
# #T_ce03c_row30_col5 {
#   width: 10em;
# }
# #T_ce03c_row31_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, yellowgreen 4.4%, transparent 4.4%);
# }
# #T_ce03c_row32_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, yellowgreen 12.0%, transparent 12.0%);
# }
# #T_ce03c_row34_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, yellowgreen 0.0%, transparent 0.0%);
# }
# </style>
# <table id="T_ce03c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ce03c_level0_col0" class="col_heading level0 col0" >State or UT code</th>
#       <th id="T_ce03c_level0_col1" class="col_heading level0 col1" >State or UT</th>
#       <th id="T_ce03c_level0_col2" class="col_heading level0 col2" >Total</th>
#       <th id="T_ce03c_level0_col3" class="col_heading level0 col3" >Male</th>
#       <th id="T_ce03c_level0_col4" class="col_heading level0 col4" >Female</th>
#       <th id="T_ce03c_level0_col5" class="col_heading level0 col5" >Difference</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce03c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ce03c_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_ce03c_row0_col1" class="data row0 col1" >Jammu and Kashmir</td>
#       <td id="T_ce03c_row0_col2" class="data row0 col2" >2008670</td>
#       <td id="T_ce03c_row0_col3" class="data row0 col3" >1080662</td>
#       <td id="T_ce03c_row0_col4" class="data row0 col4" >927982</td>
#       <td id="T_ce03c_row0_col5" class="data row0 col5" >152680</td>
#     </tr>
#     <tr>
#       <th id="T_ce03c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ce03c_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_ce03c_row1_col1" class="data row1 col1" >Himachal Pradesh</td>
#       <td id="T_ce03c_row1_col2" class="data row1 col2" >763864</td>
#       <td id="T_ce03c_row1_col3" class="data row1 col3" >400681</td>
#       <td id="T_ce03c_row1_col4" class="data row1 col4" >363183</td>
#       <td id="T_ce03c_row1_col5" class="data row1 col5" >37498</td>
#     </tr>
#     <tr>
#       <th id="T_ce03c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ce03c_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_ce03c_row2_col1" class="data row2 col1" >Punjab</td>
#       <td id="T_ce03c_row2_col2" class="data row2 col2" >2941570</td>
#       <td id="T_ce03c_row2_col3" class="data row2 col3" >1593262</td>
#       <td id="T_ce03c_row2_col4" class="data row2 col4" >1348308</td>
#       <td id="T_ce03c_row2_col5" class="data row2 col5" >244954</td>
#     </tr>
#     <tr>
#       <th id="T_ce03c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ce03c_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_ce03c_row3_col1" class="data row3 col1" >Chandigarh</td>
#       <td id="T_ce03c_row3_col2" class="data row3 col2" >117953</td>
#       <td id="T_ce03c_row3_col3" class="data row3 col3" >63187</td>
#       <td id="T_ce03c_row3_col4" class="data row3 col4" >54766</td>
#       <td id="T_ce03c_row3_col5" class="data row3 col5" >8421</td>
#     </tr>
#     <tr>
#       <th id="T_ce03c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ce03c_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_ce03c_row4_col1" class="data row4 col1" >Uttarakhand</td>
#       <td id="T_ce03c_row4_col2" class="data row4 col2" >1328844</td>
#       <td id="T_ce03c_row4_col3" class="data row4 col3" >704769</td>
#       <td id="T_ce03c_row4_col4" class="data row4 col4" >624075</td>
#       <td id="T_ce03c_row4_col5" class="data row4 col5" >80694</td>
#     </tr>
#     <tr>
#       <th id="T_ce03c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ce03c_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_ce03c_row5_col1" class="data row5 col1" >Haryana</td>
#       <td id="T_ce03c_row5_col2" class="data row5 col2" >3297724</td>
#       <td id="T_ce03c_row5_col3" class="data row5 col3" >1802047</td>
#       <td id="T_ce03c_row5_col4" class="data row5 col4" >1495677</td>
#       <td id="T_ce03c_row5_col5" class="data row5 col5" >306370</td>
#     </tr>
#     <tr>
#       <th id="T_ce03c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ce03c_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_ce03c_row6_col1" class="data row6 col1" >Delhi</td>
#       <td id="T_ce03c_row6_col2" class="data row6 col2" >1970510</td>
#       <td id="T_ce03c_row6_col3" class="data row6 col3" >1055735</td>
#       <td id="T_ce03c_row6_col4" class="data row6 col4" >914775</td>
#       <td id="T_ce03c_row6_col5" class="data row6 col5" >140960</td>
#     </tr>
#     <tr>
#       <th id="T_ce03c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ce03c_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_ce03c_row7_col1" class="data row7 col1" >Rajasthan</td>
#       <td id="T_ce03c_row7_col2" class="data row7 col2" >10504916</td>
#       <td id="T_ce03c_row7_col3" class="data row7 col3" >5580212</td>
#       <td id="T_ce03c_row7_col4" class="data row7 col4" >4924004</td>
#       <td id="T_ce03c_row7_col5" class="data row7 col5" >656208</td>
#     </tr>
#     <tr>
#       <th id="T_ce03c_leve

# %%
df[['Male','Female']].describe().T
# Out:
#         count            mean             std     min      25%        50%  \
# Male     35.0  2370059.685714  3303239.135753  3715.0  93697.5  1080662.0
# Female   35.0  2166756.885714  3000401.399059  3373.0  90450.5   927982.0
#
#               75%         max
# Male    3535097.5  15653175.0
# Female  3340213.5  14075060.0

# %% [markdown]
# ---

# %% [markdown]
# **упражнения**
#
# https://github.com/ajcr/100-pandas-puzzles

# %% [markdown]
# ---

# %%
# # !pip3 install watermark
# # Python package versions used
# %load_ext watermark
# %watermark --python
# %watermark --iversions
# #

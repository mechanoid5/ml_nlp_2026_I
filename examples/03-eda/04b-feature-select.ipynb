# %% [markdown]
# **EDA / Exploratory Data Analysis**
#
# Евгений Борисов esborisov@sevsu.ru

# %% [markdown]
# * проверка на пропуски
# * проверка на дубликаты
# * проверка на противоречивую разметку
# * статистические характеристики: корреляции, распределения, персентили
# * поиск аномалий
# * визуализация, признаки попарно, PCA, статистики

# %%
import numpy as np
import pandas as pd

# %%
np.set_printoptions(precision=3)
pd.options.display.float_format = '{:,.3f}'.format

# %% [markdown]
# #  загружаем данные

# %%
# pip install ucimlrepo

# %%
from ucimlrepo import fetch_ucirepo 
data = fetch_ucirepo(id=186)

# %% [markdown]
# # изучаем структуру

# %%
display( list(data) )
# Out:
# ['data', 'metadata', 'variables']

# %%
display( list(data['metadata']) )
# Out:
# ['uci_id',
#  'name',
#  'repository_url',
#  'data_url',
#  'abstract',
#  'area',
#  'tasks',
#  'characteristics',
#  'num_instances',
#  'num_features',
#  'feature_types',
#  'demographics',
#  'target_col',
#  'index_col',
#  'has_missing_values',
#  'missing_values_symbol',
#  'year_of_dataset_creation',
#  'last_updated',
#  'dataset_doi',
#  'creators',
#  'intro_paper',
#  'additional_info']

# %%
print(data['metadata']['abstract'])
# Out:
# Two datasets are included, related to red and white vinho verde wine samples, from the north of Portugal. The goal is to model wine quality based on physicochemical tests (see [Cortez et al., 2009], http://www3.dsi.uminho.pt/pcortez/wine/).

# %%
# !mkdir data

# %%
# with open('data/metadata-abstract.txt','wt') as f: f.write(data['metadata']['abstract'])

# %%
display( data['variables'] )
# Out:
#                     name     role         type demographic  \
# 0          fixed_acidity  Feature   Continuous        None
# 1       volatile_acidity  Feature   Continuous        None
# 2            citric_acid  Feature   Continuous        None
# 3         residual_sugar  Feature   Continuous        None
# 4              chlorides  Feature   Continuous        None
# 5    free_sulfur_dioxide  Feature   Continuous        None
# 6   total_sulfur_dioxide  Feature   Continuous        None
# 7                density  Feature   Continuous        None
# 8                     pH  Feature   Continuous        None
# 9              sulphates  Feature   Continuous        None
# 10               alcohol  Feature   Continuous        None
# 11               quality   Target      Integer        None
# 12                 color    Other  Categorical        None
#
#                description units missing_values
# 0                     None  None             no
# 1                     None  None             no
# 2                     None  None             no
# 3                     None  None             no
# 4                     None  None             no
# 5                     None  None             no
# 6                     None  None             no
# 7                     None  None             no
# 8                     None  None             no
# 9                     None  None             no
# 10                    None  None             no
# 11  score between 0 and 10  None             no
# 12            red or white  None             no

# %%
# data['variables'].to_csv('data/variables.csv',sep='\t',index=False)

# %%
list(data['data'])
# Out:
# ['ids', 'features', 'targets', 'original', 'headers']

# %%
display(data['data']['original'])
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0             7.400             0.700        0.000           1.900      0.076
# 1             7.800             0.880        0.000           2.600      0.098
# 2             7.800             0.760        0.040           2.300      0.092
# 3            11.200             0.280        0.560           1.900      0.075
# 4             7.400             0.700        0.000           1.900      0.076
# ...             ...               ...          ...             ...        ...
# 6492          6.200             0.210        0.290           1.600      0.039
# 6493          6.600             0.320        0.360           8.000      0.047
# 6494          6.500             0.240        0.190           1.200      0.041
# 6495          5.500             0.290        0.300           1.100      0.022
# 6496          6.000             0.210        0.380           0.800      0.020
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                  11.000                34.000    0.998 3.510      0.560
# 1                  25.000                67.000    0.997 3.200      0.680
# 2                  15.000                54.000    0.997 3.260      0.650
# 3                  17.000                60.000    0.998 3.160      0.580
# 4                  11.000                34.000    0.998 3.510      0.560
# ...                   ...                   ...      ...   ...        ...
# 6492               24.000                92.000    0.991 3.270      0.500
# 6493               57.000               168.000    0.995 3.150      0.460
# 6494               30.000               111.000    0.993 2.990      0.460
# 6495               20.000               110.000    0.989 3.340      0.380
# 6496               22.000                98.000    0.989 3.260      0.320
#
#       alcohol  quality  color
# 0       9.400        5    red
# 1       9.800        5    red
# 2       9.800        5    red
# 3       9.800        6    red
# 4       9.400        5    red
# ...       ...      ...    ...
# 6492   11.200        6  white
# 6493    9.600        5  white
# 6494    9.400        6  white
# 6495   12.800        7  white
# 6496   11.800        6  white
#
# [6497 rows x 13 columns]

# %%
df = data['data']['original']
display(len(df))
display(df.sample(3))
# Out:
# 6497
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 6366          6.600             0.190        0.250           1.200      0.052
# 3621          7.600             0.340        0.390           7.600      0.040
# 938           7.200             0.380        0.380           2.800      0.068
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 6366               34.000               181.000    0.994 3.300      0.420
# 3621               45.000               215.000    0.997 3.110      0.530
# 938                23.000                42.000    0.994 3.340      0.720
#
#       alcohol  quality  color
# 6366    9.400        7  white
# 3621    9.200        6  white
# 938    12.900        7    red

# %%
del data

# %%
# df.to_csv('data/data.csv',sep='\t',index=False)

# %%
# df = pd.read_csv('data/data.csv',sep='\t')
# display(len(df))
# display(df.sample(3))

# %%
# df['id'] = range(len(df))

# %% [markdown]
# # изучение и визуализация данных

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed_acidity         6497 non-null   float64
#  1   volatile_acidity      6497 non-null   float64
#  2   citric_acid           6497 non-null   float64
#  3   residual_sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free_sulfur_dioxide   6497 non-null   float64
#  6   total_sulfur_dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
#  12  color                 6497 non-null   object
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %%
set(df['color'])
# Out:
# {'red', 'white'}

# %%
# заменяем название на номер
df['color_'] = pd.Categorical(df['color']).codes

# %%
set(df['quality'])
# Out:
# {3, 4, 5, 6, 7, 8, 9}

# %%
# сквозная нумерация классов от нуля
# df['target'] = pd.Categorical(df['quality']).codes 
df['target'] = df['quality']

# %%
display(df.sample(4))
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 1814          5.800             0.260        0.240           9.200      0.044
# 6265          6.400             0.310        0.530           8.800      0.057
# 5156          8.100             0.200        0.280           0.900      0.023
# 5572          6.300             0.270        0.510           7.600      0.049
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 1814               55.000               152.000    0.996 3.310      0.380
# 6265               36.000               221.000    0.996 3.170      0.440
# 5156               49.000                87.000    0.991 2.920      0.360
# 5572               35.000               200.000    0.995 3.160      0.540
#
#       alcohol  quality  color  color_  target
# 1814    9.400        5  white       1       5
# 6265    9.100        5  white       1       5
# 5156   11.100        6  white       1       6
# 5572    9.400        4  white       1       4

# %%
# список признаков
cols_features =[
#    'id',
    'fixed_acidity',
    'volatile_acidity',
    'citric_acid',
    'residual_sugar',
    'chlorides',
    'free_sulfur_dioxide',
    'total_sulfur_dioxide',
    'density',
    'pH',
    'sulphates',
    'alcohol',
#    'color',
    'color_',
#    'target'
#    'quality',    
]

# %% [markdown]
# ## проверка на пропуски

# %%
df.isna().any()
# Out:
# fixed_acidity           False
# volatile_acidity        False
# citric_acid             False
# residual_sugar          False
# chlorides               False
# free_sulfur_dioxide     False
# total_sulfur_dioxide    False
# density                 False
# pH                      False
# sulphates               False
# alcohol                 False
# quality                 False
# color                   False
# color_                  False
# target                  False
# dtype: bool

# %%
# from sklearn.impute import KNNImputer
# Метод ближайших соседей (KNN): учитывает значения признаков ближайших объектов для заполнения пропусков. 
# Перед применением метода нужно закодировать или удалить категориальные признаки, работает только с числовыми.

# %% [markdown]
# ## проверка на дубликаты

# %%
# проверка на дубликаты
display( len(df) )
display( len( df[cols_features].drop_duplicates() ) )
display( len( df[cols_features+['target']].drop_duplicates() ) )
# ЕСТЬ ДУБЛИКАТЫ ЗАПИСЕЙ
# Out:
# 6497
# 5320
# 5320

# %%
# удаляем дубликаты
# display( len(df) )
# df = df.drop_duplicates(cols_features+['target']).reset_index(drop=True)
# display( len(df) )
# display( df.sample(3) )

# %% [markdown]
# ## проверка на противоречивую разметку

# %%
# проверка на противоречивую разметку
# т.е. таблица НЕ должна содержать одинаковых но разноразмеченных примеров
assert (df.groupby(cols_features)['target'].apply(set).reset_index()['target'].str.len()==1).all()

# %% [markdown]
# ## сбалансированность датасета

# %%
df['id'] = range(len(df))
df.groupby('target')[['id']].count().T #.`plot.barh()
# датасет не сбалансирован
# Out:
# target   3    4     5     6     7    8  9
# id      30  216  2138  2836  1079  193  5

# %% [markdown]
# ## распределения признаков

# %%
from matplotlib import pyplot as plt

# %%
# import seaborn as sns
# sns.pairplot(df[cols_features+['target']], hue='target',palette='viridis')
# plt.show()

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(
        df[cols_features], 
        figsize=(26, 26), 
        diagonal='hist', 
        alpha=.7, 
        s=5, 
        marker='o',
        c=df['target'],
        cmap='rainbow',    
    )
plt.show()

# %%
# сбалансированность датасета
df['id'] = range(len(df))
display( df.groupby('target')[['id']].count().T )
# 9-тый target - очень мало значений для анализа
# Out:
# target   3    4     5     6     7    8  9
# id      30  216  2138  2836  1079  193  5

# %%
# распределения признаков
n_cols_plot = 3
n_features = len(cols_features)
n_rows_plot = int(np.ceil(len(cols_features)/n_cols_plot))

fig = plt.figure( figsize=(4*n_cols_plot,3*n_rows_plot) )
for n,f in enumerate(cols_features):
    ax = plt.subplot(n_rows_plot,n_cols_plot,n+1) 
    # 9-тый target - очень мало значений для анализа
    df[df['target']!=9].groupby('target')[f].plot.kde(ax=ax)
    ax.set_title(f)
    ax.grid()

handles, labels = plt.gca().get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center',ncol=n_features-1)  
plt.tight_layout()
plt.show()

# %% [markdown]
# ## зависимость признаков и таргета

# %%
df_corr = df[cols_features+['target']].corr()
display( df_corr.style.background_gradient(axis=None, vmin=-1, vmax=1, cmap='rainbow') )
# Out:
# <style type="text/css">
# #T_bdfd3_row0_col0, #T_bdfd3_row1_col1, #T_bdfd3_row2_col2, #T_bdfd3_row3_col3, #T_bdfd3_row4_col4, #T_bdfd3_row5_col5, #T_bdfd3_row6_col6, #T_bdfd3_row7_col7, #T_bdfd3_row8_col8, #T_bdfd3_row9_col9, #T_bdfd3_row10_col10, #T_bdfd3_row11_col11, #T_bdfd3_row12_col12 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_bdfd3_row0_col1, #T_bdfd3_row1_col0, #T_bdfd3_row1_col9, #T_bdfd3_row9_col1 {
#   background-color: #b9ef92;
#   color: #000000;
# }
# #T_bdfd3_row0_col2, #T_bdfd3_row2_col0 {
#   background-color: #d2de81;
#   color: #000000;
# }
# #T_bdfd3_row0_col3, #T_bdfd3_row3_col0 {
#   background-color: #62fbc4;
#   color: #000000;
# }
# #T_bdfd3_row0_col4, #T_bdfd3_row0_col9, #T_bdfd3_row4_col0, #T_bdfd3_row9_col0 {
#   background-color: #cce385;
#   color: #000000;
# }
# #T_bdfd3_row0_col5, #T_bdfd3_row5_col0 {
#   background-color: #37e6d8;
#   color: #000000;
# }
# #T_bdfd3_row0_col6, #T_bdfd3_row2_col8, #T_bdfd3_row6_col0, #T_bdfd3_row8_col2, #T_bdfd3_row8_col11, #T_bdfd3_row11_col8 {
#   background-color: #2adddd;
#   color: #000000;
# }
# #T_bdfd3_row0_col7, #T_bdfd3_row7_col0 {
#   background-color: #f4c069;
#   color: #000000;
# }
# #T_bdfd3_row0_col8, #T_bdfd3_row4_col10, #T_bdfd3_row8_col0, #T_bdfd3_row10_col4 {
#   background-color: #3febd5;
#   color: #000000;
# }
# #T_bdfd3_row0_col10, #T_bdfd3_row10_col0 {
#   background-color: #66fcc2;
#   color: #000000;
# }
# #T_bdfd3_row0_col11, #T_bdfd3_row9_col11, #T_bdfd3_row11_col0, #T_bdfd3_row11_col9 {
#   background-color: #02b7eb;
#   color: #f1f1f1;
# }
# #T_bdfd3_row0_col12, #T_bdfd3_row12_col0 {
#   background-color: #6dfdbf;
#   color: #000000;
# }
# #T_bdfd3_row1_col2, #T_bdfd3_row2_col1 {
#   background-color: #1fd3e1;
#   color: #000000;
# }
# #T_bdfd3_row1_col3, #T_bdfd3_row3_col1, #T_bdfd3_row4_col12, #T_bdfd3_row12_col4 {
#   background-color: #4df3ce;
#   color: #000000;
# }
# #T_bdfd3_row1_col4, #T_bdfd3_row4_col1 {
#   background-color: #e0d377;
#   color: #000000;
# }
# #T_bdfd3_row1_col5, #T_bdfd3_row5_col1 {
#   background-color: #24d8df;
#   color: #000000;
# }
# #T_bdfd3_row1_col6, #T_bdfd3_row6_col1 {
#   background-color: #14cae5;
#   color: #000000;
# }
# #T_bdfd3_row1_col7, #T_bdfd3_row7_col1 {
#   background-color: #c4e88a;
#   color: #000000;
# }
# #T_bdfd3_row1_col8, #T_bdfd3_row7_col9, #T_bdfd3_row8_col1, #T_bdfd3_row9_col7 {
#   background-color: #c2ea8c;
#   color: #000000;
# }
# #T_bdfd3_row1_col10, #T_bdfd3_row3_col12, #T_bdfd3_row10_col1, #T_bdfd3_row12_col3 {
#   background-color: #76ffb9;
#   color: #000000;
# }
# #T_bdfd3_row1_col11, #T_bdfd3_row11_col1 {
#   background-color: #2884f6;
#   color: #f1f1f1;
# }
# #T_bdfd3_row1_col12, #T_bdfd3_row3_col8, #T_bdfd3_row6_col10, #T_bdfd3_row8_col3, #T_bdfd3_row10_col6, #T_bdfd3_row12_col1 {
#   background-color: #3ae8d6;
#   color: #000000;
# }
# #T_bdfd3_row2_col3, #T_bdfd3_row3_col2 {
#   background-color: #a4f89f;
#   color: #000000;
# }
# #T_bdfd3_row2_col4, #T_bdfd3_row4_col2, #T_bdfd3_row6_col7, #T_bdfd3_row7_col6, #T_bdfd3_row9_col12, #T_bdfd3_row10_col11, #T_bdfd3_row11_col10, #T_bdfd3_row12_col9 {
#   background-color: #88ffaf;
#   color: #000000;
# }
# #T_bdfd3_row2_col5, #T_bdfd3_row5_col2 {
#   background-color: #a2f9a0;
#   color: #000000;
# }
# #T_bdfd3_row2_col6, #T_bdfd3_row6_col2, #T_bdfd3_row8_col9, #T_bdfd3_row9_col8 {
#   background-color: #b0f397;
#   color: #000000;
# }
# #T_bdfd3_row2_col7, #T_bdfd3_row7_col2 {
#   background-color: #99fca6;
#   color: #000000;
# }
# #T_bdfd3_row2_col9, #T_bdfd3_row5_col12, #T_bdfd3_row9_col2, #T_bdfd3_row12_col5 {
#   background-color: #8efeac;
#   color: #000000;
# }
# #T_bdfd3_row2_col10, #T_bdfd3_row10_col2 {
#   background-color: #7dffb6;
#   color: #000000;
# }
# #T_bdfd3_row2_col11, #T_bdfd3_row11_col2 {
#   background-color: #aef498;
#   color: #000000;
# }
# #T_bdfd3_row2_col12, #T_bdfd3_row12_col2 {
#   background-color: #94fda8;
#   color: #000000;
# }
# #T_bdfd3_row3_col4, #T_bdfd3_row4_col3 {
#   background-color: #5efac6;
#   color: #000000;
# }
# #T_bdfd3_row3_col5, #T_bdfd3_row5_col3 {
#   background-color: #e6cd73;
#   color: #000000;
# }
# #T_bdfd3_row3_col6, #T_bdfd3_row6_col3 {
#   background-color: #feb562;
#   color: #000000;
# }
# #T_bdfd3_row3_col7, #T_bdfd3_row7_col3 {
#   background-color: #ffa558;
#   color: #000000;
# }
# #T_bdfd3_row3_col9, #T_bdfd3_row5_col10, #T_bdfd3_row9_col3, #T_bdfd3_row10_col5 {
#   background-color: #50f4cc;
#   color: #000000;
# }
# #T_bdfd3_row3_col10, #T_bdfd3_row10_col3 {
#   background-color: #22d6e0;
#   color: #000000;
# }
# #T_bdfd3_row3_col11, #T_bdfd3_row11_col3 {
#   background-color: #d9da7d;
#   color: #000000;
# }
# #T_bdfd3_row4_col5, #T_bdfd3_row5_col4, #T_bdfd3_row5_col9, #T_bdfd3_row9_col5 {
#   background-color: #4ef3cd;
#   color: #000000;
# }
# #T_bdfd3_row4_col6, #T_bdfd3_row6_col4, #T_bdfd3_row6_col9, #T_bdfd3_row9_col6 {
#   background-color: #38e7d7;
#   color: #000000;
# }
# #T_bdfd3_row4_col7, #T_bdfd3_row7_col4 {
#   background-color: #dcd67a;
#   color: #000000;
# }
# #T_bdfd3_row4_col8, #T_bdfd3_row8_col4 {
#   background-color: #8bfeae;
#   color: #000000;
# }
# #T_bdfd3_row4_col9, #T_bdfd3_row9_col4 {
#   background-color: #e4cf74;
#   color: #000000;
# }
# #T_bdfd3_row4_col11, #T_bdfd3_row11_col4 {
#   background-color: #04b0ed;
#   color: #f1f1f1;
# }
# #T_bdfd3_row5_col6, #T_bdfd3_row6_col5 {
#   background-color: #ff6b37;
#   color: #f1f1f1;
# }
# #T_bdfd3_row5_col7, #T_bdfd3_row7_col5 {
#   background-color: #86ffb0;
#   color: #000000;
# }
# #T_bdfd3_row5_col8, #T_bdfd3_row8_col5 {
#   background-color: #5af8c8;
#   color: #000000;
# }
# #T_bdfd3_row5_col11, #T_bdfd3_row11_col5 {
#   background-color: #f9bb66;
#   color: #000000;
# }
# #T_bdfd3_row6_col8, #T_bdfd3_row8_col6 {
#   background-color: #42edd3;
#   color: #000000;
# }
# #T_bdfd3_row6_col11, #T_bdfd3_row11_col6 {
#   background-color: #ff733b;
#   color: #f1f1f1;
# }
# #T_bdfd3_row6_col12, #T_bdfd3_row12_col6 {
#   background-color: #74feba;
#   color: #000000;
# }
# #T_bdfd3_row7_col8, #T_bdfd3_row8_col7 {
#   background-color: #82ffb3;
#   color: #000000;
# }
# #T_bdfd3_row7_col10, #T_bdfd3_row10_col7 {
#   background-color: #3079f7;
#   color: #f1f1f1;
# }
# #T_bdfd3_row7_col11, #T_bdfd3_row11_col7 {
#   background-color: #1acfe3;
#   color: #000000;
# }
# #T_bdfd3_row7_col12, #T_bdfd3_row12_col7 {
#   background-color: #30e1da;
#   color: #000000;
# }
# #T_bdfd3_row8_col10, #T_bdfd3_row10_col8, #T_bdfd3_row11_col12, #T_bdfd3_row12_col11 {
#   background-color: #9efaa2;
#   color: #000000;
# }
# #T_bdfd3_row8_col12, #T_bdfd3_row12_col8 {
#   background-color: #84ffb2;
#   color: #000000;
# }
# #T_bdfd3_row9_col10, #T_bdfd3_row10_col9 {
#   background-color: #7effb5;
#   color: #000000;
# }
# #T_bdfd3_row10_col12, #T_bdfd3_row12_col10 {
#   background-color: #f0c46c;
#   color: #000000;
# }
# </style>
# <table id="T_bdfd3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bdfd3_level0_col0" class="col_heading level0 col0" >fixed_acidity</th>
#       <th id="T_bdfd3_level0_col1" class="col_heading level0 col1" >volatile_acidity</th>
#       <th id="T_bdfd3_level0_col2" class="col_heading level0 col2" >citric_acid</th>
#       <th id="T_bdfd3_level0_col3" class="col_heading level0 col3" >residual_sugar</th>
#       <th id="T_bdfd3_level0_col4" class="col_heading level0 col4" >chlorides</th>
#       <th id="T_bdfd3_level0_col5" class="col_heading level0 col5" >free_sulfur_dioxide</th>
#       <th id="T_bdfd3_level0_col6" class="col_heading level0 col6" >total_sulfur_dioxide</th>
#       <th id="T_bdfd3_level0_col7" class="col_heading level0 col7" >density</th>
#       <th id="T_bdfd3_level0_col8" class="col_heading level0 col8" >pH</th>
#       <th id="T_bdfd3_level0_col9" class="col_heading level0 col9" >sulphates</th>
#       <th id="T_bdfd3_level0_col10" class="col_heading level0 col10" >alcohol</th>
#       <th id="T_bdfd3_level0_col11" class="col_heading level0 col11" >color_</th>
#       <th id="T_bdfd3_level0_col12" class="col_heading level0 col12" >target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bdfd3_level0_row0" class="row_heading level0 row0" >fixed_acidity</th>
#       <td id="T_bdfd3_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_bdfd3_row0_col1" class="data row0 col1" >0.219008</td>
#       <td id="T_bdfd3_row0_col2" class="data row0 col2" >0.324436</td>
#       <td id="T_bdfd3_row0_c

# %%
import seaborn as sns

mask = np.triu(np.ones_like(df_corr, dtype=bool))
plt.figure(figsize=(12,9))
sns.heatmap(
    df_corr.abs(), 
    mask=mask, 
    #center=0, 
    annot=True, 
    fmt='.2f', 
    square=True, 
    cmap='rainbow'
)
plt.show()

# %% [markdown]
# ## поиск выбросов

# %% [markdown]
# Гистограмма и ящик с усами на пальцах
# https://habr.com/ru/articles/267123/

# %% [markdown]
# ![изображение.png](attachment:c2080e5c-2d50-4535-868c-97f0381c9b2d.png)

# %% [markdown]
# Pandas boxplot
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.boxplot.html

# %%
# распределения признаков
n_cols_plot = 6
n_features = len(cols_features)
n_rows_plot = int(np.ceil(len(cols_features)/n_cols_plot))

df[cols_features].plot.box(subplots=True,layout=(n_rows_plot,n_cols_plot),figsize=(15,7),sharey=False,grid=True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ----

# %%
q = [.05,.10,.25,.50,.75,.90,.95]
df[cols_features].describe(q).T
# Out:
#                          count    mean    std   min     5%    10%    25%  \
# fixed_acidity        6,497.000   7.215  1.296 3.800  5.700  6.000  6.400
# volatile_acidity     6,497.000   0.340  0.165 0.080  0.160  0.180  0.230
# citric_acid          6,497.000   0.319  0.145 0.000  0.050  0.140  0.250
# residual_sugar       6,497.000   5.443  4.758 0.600  1.200  1.300  1.800
# chlorides            6,497.000   0.056  0.035 0.009  0.028  0.031  0.038
# free_sulfur_dioxide  6,497.000  30.525 17.749 1.000  6.000  9.000 17.000
# total_sulfur_dioxide 6,497.000 115.745 56.522 6.000 19.000 30.000 77.000
# density              6,497.000   0.995  0.003 0.987  0.990  0.991  0.992
# pH                   6,497.000   3.219  0.161 2.720  2.970  3.020  3.110
# sulphates            6,497.000   0.531  0.149 0.220  0.350  0.370  0.430
# alcohol              6,497.000  10.492  1.193 8.000  9.000  9.100  9.500
# color_               6,497.000   0.754  0.431 0.000  0.000  0.000  1.000
#
#                          50%     75%     90%     95%     max
# fixed_acidity          7.000   7.700   8.800   9.800  15.900
# volatile_acidity       0.290   0.400   0.590   0.670   1.580
# citric_acid            0.310   0.390   0.490   0.560   1.660
# residual_sugar         3.000   8.100  13.000  15.000  65.800
# chlorides              0.047   0.065   0.086   0.102   0.611
# free_sulfur_dioxide   29.000  41.000  54.000  61.000 289.000
# total_sulfur_dioxide 118.000 156.000 188.000 206.000 440.000
# density                0.995   0.997   0.998   0.999   1.039
# pH                     3.210   3.320   3.420   3.500   4.010
# sulphates              0.510   0.600   0.720   0.790   2.000
# alcohol               10.300  11.300  12.300  12.700  14.900
# color_                 1.000   1.000   1.000   1.000   1.000

# %%
# df.clip?

# %%
# from sklearn.linear_model import RANSACRegressor

# %% [markdown]
# ----

# %% [markdown]
# Выявляем аномалии с помощью Isolation Forest
# https://habr.com/ru/companies/otus/articles/881086/

# %% [markdown]
# * Строим дерево, где каждый узел случайно выбирает один признак и случайное значение разбиения.
# * Рекурсивно делим данные, пока каждая точка не окажется в своём отдельном листе.
# * Считаем аномальность точки по тому, насколько быстро она была изолирована (чем короче путь, тем аномальнее).

# %%
# IsolationForest?

# %%
from sklearn.ensemble import IsolationForest

df['is_anomaly'] = IsolationForest(contamination=0.01).fit_predict(df[cols_features])==-1

# %%
df.groupby(['target','is_anomaly'])[['id']].count()
# Out:
#                      id
# target is_anomaly
# 3      False         15
#        True          15
# 4      False        199
#        True          17
# 5      False       2017
#        True         121
# 6      False       2723
#        True         113
# 7      False       1028
#        True          51
# 8      False        185
#        True           8
# 9      False          5

# %%
from sklearn.decomposition import PCA
X2 = PCA(n_components=2).fit_transform(df[cols_features].values)
display( X2.shape )

# %%
fig, ax = plt.subplots(figsize=(7,5))
ax.scatter(X2[df['is_anomaly'], 0], X2[df['is_anomaly'], 1],label='outliers',s=1,c='r')
ax.scatter(X2[~df['is_anomaly'], 0], X2[~df['is_anomaly'], 1],label='inliers',s=1,c='b',alpha=0.1)
ax.grid()
ax.legend()
plt.show()

# %%
# df_anom = df.query('is_anomaly').reset_index(drop=True)
# df = df.query('~is_anomaly').reset_index(drop=True)
# display( len(df),len(df_anom) )

# %% [markdown]
# ## отбор признаков

# %% [markdown]
# Построение и отбор признаков. Часть 2: feature selection
# https://proglib.io/p/postroenie-i-otbor-priznakov-chast-2-feature-selection-2021-09-25
#
# Методы отбора фич
# https://habr.com/ru/articles/264915/
#
# Отбор признаков в задачах машинного обучения. Часть 1
# https://habr.com/ru/articles/550978/

# %% [raw]
# Количество пропущенных значений (удаляются признаки у которых процент пропущенных значений больше порогового).
#
# Коэффициент корреляции (удаляются признаки, у которых коэффициент корреляции больше порогового).
#
# Вариативность (удаляются признаки, состоящие из одного значения).
#
# Оценка важности признаков с помощью lightgbm
# (удаляются признаки, имеющие низкую важность в модели lightgbm.
# Следует применять только если lightgbm имеет хорошую точность.)
#
#
# VarianceThreshold отбирает признаки, у которых дисперсия меньше заданного значения.
#
# SelectKBest и SelectPercentile оценивают взаимосвязь предикторов с целевой переменной используя статистические тесты,
# позволяя отобрать соответственно заданное количество и долю наилучших по заданному критерию признаков.
# В качестве статистических тестов используются F-тест,
#
#
# F-тест оценивает степень линейной зависимости между предикторами и целевой переменной,
# поэтому он лучше всего подойдёт для линейных моделей.
# Реализован в sklearn как f_regression и f_classif соответственно для регрессии и классификации.
#
# X2 тест используется в задах классификации и оценивает зависимость между признаками и классами целевой пременной.
# Стоит отметить, что этот тип тестов требует неотрицательных и правильно отмасштабированных признаков.
#
# mutual_info_regression / mutual_info_classif - взаимная информация показывает насколько чётко определена целевая переменная если известны значения предиктора. Этот тип тестов считается самым удобным в использовании - он хорошо работает "из коробки" и позволяет находить нелинейные зависимости.

# %%
# X = df[cols_features_].values
# X = df[cols_features].values

# %%
# import matplotlib.pyplot as plt
from sklearn.feature_selection import mutual_info_classif

#importances = mutual_info_classif(df[cols_features].values, df['target_'].values)
importances = mutual_info_classif(df[cols_features].values, df['target'].values)
importances = pd.Series(importances, cols_features).sort_values()
importances.plot(kind='barh', color='teal',grid=True)
plt.show()

# %%
cols_features_ = list(importances.sort_values(ascending=False).head(5).index)
cols_features_

# %%
# from pandas.plotting import scatter_matrix
# # from matplotlib import colors as mcolors
# # colors = list(mcolors.CSS4_COLORS.keys()) 
# # colors = np.random.permutation(colors)
# colors = ['blue','green','red','cyan','magenta','yellow','black',]
# colors = { n:c for n,c in enumerate(colors) }

# scatter_matrix(
#         df[cols_features_], 
#         figsize=(7,7), 
#         diagonal='kde', 
#         alpha=.5, 
#         s=4, 
#         color=df['target'].map(colors) 
#     )
# plt.show()

# %%
import seaborn as sns
sns.pairplot(df[cols_features_+['target']], hue='target',palette='rainbow')
#sns.pairplot(df[cols_features_+['target_']], hue='target_',palette='viridis')
plt.show()

# %%
# from sklearn.feature_selection import SelectKBest
# from sklearn.feature_selection import chi2
# fsel = SelectKBest(chi2, k=4).fit( df[cols_features], df['target'])
# fsel.pvalues_
# # X = SelectKBest(chi2, k=4).fit_transform( df[cols_features], df['target'])

# %%
# from sklearn.feature_selection import RFE
# from sklearn.svm import SVR
# support = RFE(SVR(kernel="linear"), n_features_to_select=5, step=1).fit(df[cols_features].values, df['target'].values ).support_

# %%
# X = df[cols_features_].values
X = df[cols_features].values
# y = df['target_'].values
y = df['target'].values
display( X.shape,y.shape )

# %%
from sklearn.decomposition import PCA
X2 = PCA(n_components=2).fit_transform(X)
display( X2.shape )

# %%
# from sklearn.manifold import TSNE
# X2 = TSNE(n_components=2).fit_transform(X)
# display( X2.shape )

# %%
fig, ax = plt.subplots(figsize=(7,7))
for c in sorted(set(y)): # for c in [3,4]: 
    ax.scatter(X2[y==c, 0], X2[y==c, 1],s=1,label=f'{c}')
ax.grid()
ax.legend()
plt.show()

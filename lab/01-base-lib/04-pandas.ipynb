# %% [markdown]
# __лабораторная работа N1:__ средства языка Python для работы с данными
#
# __часть 4:__  библиотека  pandas, работа с табличными данными

# %% [markdown]
# __цель:__ изучить возможности библиотеки pandas

# %% [markdown]
# __порядок выполнения:__ выполните задания представленные ниже

# %% [markdown]
# __литература__
#
# Моя шпаргалка по pandas
# https://habr.com/ru/companies/ruvds/articles/494720/
#
# 100 pandas puzzles
# https://github.com/ajcr/100-pandas-puzzles022

# %% [markdown]
# # Импортируйте пакет pandas

# %% [markdown]
# # Распечатайте версию pandas

# %% [markdown]
# # Сгенерируйте вектор случайных значений numpy размером 1000, создайте из него DataFrame, имя колонки 'x'

# %% [markdown]
# # Посчитайте минимальное и мексимальное значение столбца 'x', а также медиану и квартили

# %% [markdown]
# # Нарисуйте график плотности распределения 'х'

# %% [markdown]
# # Нарисуйте блочную диаграмму с ограничителями выбросов ("ящик с усами") для 'х'

# %% [markdown]
# # Отфильтруйте все значения меньше 0.8 для 'х'

# %% [markdown]
# # Замените все значения меньше 0.3 на 0
